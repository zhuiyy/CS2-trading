# %%
from cs2_trading.agents.DataReducingAgent import DataReducingAgent
from cs2_trading.agents.StickerAgent import StickerAgent
from openai import OpenAI
from dotenv import load_dotenv
import os
from cs2_trading.data.api import InfoAPI

# %%
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_API_BASE_URL"),
)

# %%
load_dotenv()

info_api = InfoAPI(os.getenv("INFO_API_TOKEN"))

# %%
data_reducing_agent = DataReducingAgent(client=client, llm_model="qwen-plus")

# %%
#info = info_api.get_good_info(7703)
#data_reducing_agent.work(info)

# %%
sticker_agents = StickerAgent(client=client, llm_model="qwen-plus", info_api=info_api)
sticker_agents.work('''一日蒸发20亿美元！CS2游戏饰品市场迎剧变 有职业选手已经“清仓”
头像
财联社

2025-10-24 11:47发布于上海上海报业集团旗下《财联社》官方账号

关注
《科创板日报》10月24日讯 仅仅一天，《CS2》玩家们的天塌了。

昨日，《CS2》游戏饰品市场剧烈震荡，指数日K上收出一根大阴线，饰品总市场估值从59亿美元暴跌至42亿美元，一日蒸发近20亿美元。其中，高端饰品迎来集体跳水。据《科创板日报》统计，包括专业手套、蝴蝶刀在内的一众稀有道具，单日内普遍跌超50%。''')
# Out:
# finder []
# No stickers found, general advice given.
# '【CS2印花饰品市场剧变分析】近期《CS2》饰品市场单日蒸发20亿美元，总市值从59亿骤降至42亿，高端饰品如专业手套、蝴蝶刀等普遍暴跌超50%，堪称历史性崩盘。此次回调虽未伴随V社官方政策变动，但结合金融数据与职业圈动态可见端倪：多名一线战队选手在社交媒体清仓个人饰品账户，释放强烈看空信号，引发市场恐慌性抛售。值得注意的是，当前CS2市场仍维持t+7交易机制，资金流动性受限，加剧了价格失衡下的踩踏效应。金融模型显示短期波动率已突破历史阈值，但低估了社交情绪与职业圈联动带来的“黑天鹅”风险。建议投资者暂缓抄底高稀有度单品，优先布局中低价位、高流转率的赛事纪念印花，等待市场情绪企稳后捕捉错杀机会。'
